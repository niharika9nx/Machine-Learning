# %% [markdown]
# | Feature           | Meaning                                                                |
# | ----------------- | ---------------------------------------------------------------------- |
# | **Id**            | Unique identification number of the house record.                      |
# | **MSSubClass**    | Type/class of dwelling based on its construction and age.              |
# | **MSZoning**      | General zoning classification of the property.                         |
# | **LotFrontage**   | Length of the property's street-facing boundary.                       |
# | **LotArea**       | Total area of the land/lot.                                            |
# | **Street**        | Type of road access to the property, such as paved or gravel.          |
# | **Alley**         | Type of alley access to the property.                                  |
# | **LotShape**      | Overall shape of the property lot.                                     |
# | **LandContour**   | Flatness or slope characteristics of the land.                         |
# | **Utilities**     | Type and availability of utilities such as water, gas and electricity. |
# | **LotConfig**     | Configuration or arrangement of the property lot.                      |
# | **LandSlope**     | Degree of slope of the property.                                       |
# | **Neighborhood**  | Physical location/neighborhood of the house.                           |
# | **Condition1**    | Proximity to important nearby features such as roads or railways.      |
# | **Condition2**    | Secondary proximity to nearby features such as roads or railways.      |
# | **BldgType**      | Type of residential building, such as single-family or duplex.         |
# | **HouseStyle**    | Architectural style and number of floors of the house.                 |
# | **OverallQual**   | Overall material quality and finish of the house, rated from 1–10.     |
# | **OverallCond**   | Overall condition of the house, rated from 1–9.                        |
# | **YearBuilt**     | Original year in which the house was constructed.                      |
# | **YearRemodAdd**  | Year when the house was last remodeled or renovated.                   |
# | **RoofStyle**     | Type/design of the roof.                                               |
# | **RoofMatl**      | Material used for the roof.                                            |
# | **Exterior1st**   | Primary material used on the exterior walls.                           |
# | **Exterior2nd**   | Secondary material used on the exterior walls.                         |
# | **MasVnrType**    | Type of masonry veneer used on the house exterior.                     |
# | **MasVnrArea**    | Area covered by masonry veneer.                                        |
# | **ExterQual**     | Quality of the exterior materials.                                     |
# | **ExterCond**     | Current condition of the exterior materials.                           |
# | **Foundation**    | Type of foundation supporting the house.                               |
# | **BsmtQual**      | Quality of the basement.                                               |
# | **BsmtCond**      | General condition of the basement.                                     |
# | **BsmtExposure**  | Degree to which the basement has exterior exposure/windows.            |
# | **BsmtFinType1**  | Quality/type of the main finished basement area.                       |
# | **BsmtFinSF1**    | Finished square feet of the first basement area.                       |
# | **BsmtFinType2**  | Quality/type of the second finished basement area.                     |
# | **BsmtFinSF2**    | Finished square feet of the second basement area.                      |
# | **BsmtUnfSF**     | Unfinished square feet of the basement.                                |
# | **TotalBsmtSF**   | Total basement area in square feet.                                    |
# | **Heating**       | Type of heating system used in the house.                              |
# | **HeatingQC**     | Quality and condition of the heating system.                           |
# | **CentralAir**    | Whether the house has central air conditioning.                        |
# | **Electrical**    | Type of electrical system installed in the house.                      |
# | **1stFlrSF**      | Area of the first floor in square feet.                                |
# | **2ndFlrSF**      | Area of the second floor in square feet.                               |
# | **LowQualFinSF**  | Area of low-quality finished living space.                             |
# | **GrLivArea**     | Above-ground living area in square feet.                               |
# | **BsmtFullBath**  | Number of full bathrooms located in the basement.                      |
# | **BsmtHalfBath**  | Number of half bathrooms located in the basement.                      |
# | **FullBath**      | Number of full bathrooms above ground.                                 |
# | **HalfBath**      | Number of half bathrooms above ground.                                 |
# | **BedroomAbvGr**  | Number of bedrooms above ground.                                       |
# | **KitchenAbvGr**  | Number of kitchens above ground.                                       |
# | **KitchenQual**   | Quality of the kitchen.                                                |
# | **TotRmsAbvGrd**  | Total number of rooms above ground, excluding bathrooms.               |
# | **Functional**    | Overall functionality/condition of the house.                          |
# | **Fireplaces**    | Number of fireplaces in the house.                                     |
# | **FireplaceQu**   | Quality and condition of the fireplace(s).                             |
# | **GarageType**    | Type/location of the garage.                                           |
# | **GarageYrBlt**   | Year the garage was built.                                             |
# | **GarageFinish**  | Interior finish level of the garage.                                   |
# | **GarageCars**    | Number of cars that the garage can accommodate.                        |
# | **GarageArea**    | Garage area in square feet.                                            |
# | **GarageQual**    | Quality of the garage.                                                 |
# | **GarageCond**    | Condition of the garage.                                               |
# | **PavedDrive**    | Type/extent of paving for the property's driveway.                     |
# | **WoodDeckSF**    | Area of the outdoor wood deck in square feet.                          |
# | **OpenPorchSF**   | Area of the open porch in square feet.                                 |
# | **EnclosedPorch** | Area of the enclosed porch in square feet.                             |
# | **3SsnPorch**     | Area of the three-season porch in square feet.                         |
# | **ScreenPorch**   | Area of the screened porch in square feet.                             |
# | **PoolArea**      | Area of the swimming pool in square feet.                              |
# | **PoolQC**        | Quality and condition of the swimming pool.                            |
# | **Fence**         | Quality/type of fencing around the property.                           |
# | **MiscFeature**   | Other miscellaneous feature not covered by the main variables.         |
# | **MiscVal**       | Monetary value of miscellaneous features.                              |
# | **MoSold**        | Month in which the house was sold.                                     |
# | **YrSold**        | Year in which the house was sold.                                      |
# | **SaleType**      | Type of sale transaction.                                              |
# | **SaleCondition** | Overall condition/circumstances of the sale.                           |
# | **SalePrice**     | Final selling price of the house — **the target variable**.            |

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("house_price_data.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df = df.drop('Id', axis=1)

# %%
df.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
object_columns = df.select_dtypes(include=['object']).columns
print("Object type columns:")
print(object_columns)

numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print("\nNumerical type columns:")
print(numerical_columns)
# Out:
# Object type columns:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='str')
#
# Numerical type columns:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
# ...

# %%
def classify_features(df):
    categorical_features = []
    non_categorical_features = []
    discrete_features = []
    continuous_features = []

    for column in df.columns:
        if df[column].dtype == 'object':
            if df[column].nunique() < 10:
                categorical_features.append(column)
            else:
                non_categorical_features.append(column)
        elif df[column].dtype in ['int64', 'float64']:
            if df[column].nunique() < 10:
                discrete_features.append(column)
            else:
                continuous_features.append(column)

    return categorical_features, non_categorical_features, discrete_features, continuous_features

# %%
categorical, non_categorical, discrete, continuous = classify_features(df)

# %%
print("Categorical Features:", categorical)
print("Non-Categorical Features:", non_categorical)
print("Discrete Features:", discrete)
print("Continuous Features:", continuous)
# Out:
# Categorical Features: []
# Non-Categorical Features: []
# Discrete Features: ['OverallCond', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars', 'PoolArea', 'YrSold']
# Continuous Features: ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal', 'MoSold', 'SalePrice']

# %%
categorical_features = [
    'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
    'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 'BldgType',
    'HouseStyle', 'RoofStyle', 'RoofMatl', 'MasVnrType', 'ExterQual',
    'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
    'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
    'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
    'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
    'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'
]

non_categorical_features = [
    'Neighborhood', 'Exterior1st', 'Exterior2nd'
]

discrete_features = [
    'OverallCond', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
    'BedroomAbvGr', 'KitchenAbvGr', 'Fireplaces', 'GarageCars',
    'PoolArea', 'YrSold'
]

continuous_features = [
    'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'YearBuilt',
    'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
    'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
    'GrLivArea', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea',
    'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
    'ScreenPorch', 'MiscVal', 'MoSold', 'SalePrice'
]

for col in categorical_features:
    if col in df.columns:
        df[col] = df[col].fillna(df[col].mode()[0])

for col in non_categorical_features:
    if col in df.columns:
        df[col] = df[col].fillna('missing')

for col in discrete_features:
    if col in df.columns:
        df[col] = df[col].fillna(df[col].median())

for col in continuous_features:
    if col != 'SalePrice' and col in df.columns:
        df[col] = df[col].fillna(df[col].median())

df = df.dropna(subset=['SalePrice'])

print("Total missing values:", df.isnull().sum().sum())
print("Dataset shape:", df.shape)
# Out:
# Total missing values: 0
# Dataset shape: (1460, 80)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['SalePrice'], kde=True, color='steelblue')
plt.title('SalePrice Distribution')

plt.subplot(1, 2, 2)
sns.histplot(np.log1p(df['SalePrice']), kde=True, color='teal')
plt.title('Log(SalePrice) Distribution')

plt.tight_layout()
plt.show()

print("Skewness of SalePrice     :", df['SalePrice'].skew().round(3))
print("Skewness of log(SalePrice):", np.log1p(df['SalePrice']).skew().round(3))
# Out:
# Skewness of SalePrice     : 1.883
# Skewness of log(SalePrice): 0.121

# %%
corr = df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)
print("Top 20 correlations with SalePrice:")
print(corr.head(21))
# Out:
# Top 20 correlations with SalePrice:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# MasVnrArea      0.472614
# Fireplaces      0.466929
# GarageYrBlt     0.466754
# BsmtFinSF1      0.386420
# LotFrontage     0.334771
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# Name: SalePrice, dtype: float64

# %%
top_corr_features = corr.index[:21]
plt.figure(figsize=(12, 10))
sns.heatmap(df[top_corr_features].corr(), annot=True, cmap='coolwarm', fmt='.2f', square=True)
plt.title('Correlation Heatmap (Top Features)')
plt.tight_layout()
plt.show()
